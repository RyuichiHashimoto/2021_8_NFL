# %%
from external_lib.evaluator import NFLAssignmentScorer
from lib.io import load_json
import pandas as pd

# %%
baseconfig = load_json("/work/config/baseconfig.json")

# %%
base_path = baseconfig["DataPath"];

ss = pd.read_csv(f"{base_path}/sample_submission.csv")
train_labels = pd.read_csv(f"{base_path}/train_labels.csv")

# %%
SUB_COLUMNS = ss.columns

scorer = NFLAssignmentScorer(train_labels)
print(scorer.score(ss))

perfect_impacts = train_labels.query("isDefinitiveImpact == True and isSideLinePlayer == False")

print(scorer.score(perfect_impacts))
# Out:
# 0.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     200             if self.has_resolvers:
# --> 201                 return self.resolvers[key]
#     202
#
# /opt/conda/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# /opt/conda/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'isDefenitiveImpact'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
